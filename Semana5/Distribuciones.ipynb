# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import special
from scipy.stats import norm

# %%
# Graficando histograma
mu, sigma = 70, 2 # media y desvio estandar
datos = np.random.normal(mu, sigma, 1000000) #creando muestra de datos

# histograma de distribución normal.
plt.hist(datos, 100)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma')
plt.show()

# %%
x_1 = np.linspace(stats.norm(mu, sigma).ppf(0.01),
                  stats.norm(mu, sigma).ppf(0.99), 100)
fda_normal = stats.norm(mu, sigma).cdf(x_1) # Función de Distribución Acumulada
plt.plot(x_1, fda_normal, label='Acumulativo')
plt.title('Función de Distribución Acumulada')
plt.ylabel('Probabilidad')
plt.xlabel('Data')
plt.legend(loc=4)
plt.show()

# %%
poisson = stats.poisson(mu) # Distribución
x = np.arange(poisson.ppf(0.01),
              poisson.ppf(0.99))
fmp = poisson.pmf(x) # Función de Masa de Probabilidad
plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Poisson')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
## Graficando Binomial
N, p = 30, 0.4 # parametros de forma 
binomial = stats.binom(N, p) # Distribución
x = np.arange(binomial.ppf(0.01),
              binomial.ppf(0.99))
fmp = binomial.pmf(x) # Función de Masa de Probabilidad
plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Binomial')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
# Graficando Chi cuadrado
def chisquare(i):
  df = i # parametro de forma.
  chi2 = stats.chi2(df)
  return chi2.pdf(x) # Función de Probabilidad


x = np.linspace(chi2.ppf(0.1),
                 chi2.ppf(0.99), 100)

plt.plot(x, chisquare(1), label="k=1")
plt.plot(x, chisquare(2), label="k=2")
plt.plot(x, chisquare(3), label="k=3")
plt.plot(x, chisquare(4), label="k=4")
plt.plot(x, chisquare(5), label="k=5")
plt.plot(x, chisquare(6), label="k=6")
plt.plot(x, chisquare(7), label="k=7")
plt.plot(x, chisquare(8), label="k=8")
plt.legend()
plt.title('Distribución Chi cuadrado')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.ylim(0,0.5)
plt.show()
