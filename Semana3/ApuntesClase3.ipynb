# %%
# !wget -cq https://raw.githubusercontent.com/DCIDA2019/da2020-Physicworld/master/datos/tabulador.csv

# %%
import pandas as pd

# %%
tabulador = pd.read_csv('tabulador.csv', encoding='Latin-1')

# %%
tabulador
# Out:
#     NIVEL TIPO  ...   PRIMA VACACIONAL          AGUINALDO
# 0      22  NaN  ...   10 Días por Año    45 Días por Año
# 1      20  NaN  ...   10 Días por Año    45 Días por Año
# 2      19  NaN  ...   10 Días por Año    45 Días por Año
# 3      19  NaN  ...   10 Días por Año    45 Días por Año
# 4      18  NaN  ...   10 Días por Año    45 Días por Año
# ..    ...  ...  ...                ...                ...
# 74      1  NaN  ...   10 Días por Año    45 Días por Año
# 75      1    A  ...   10 Días por Año    45 Días por Año
# 76      1    A  ...   10 Días por Año    45 Días por Año
# 77      1    A  ...   10 Días por Año    45 Días por Año
# 78      1    A  ...   10 Días por Año    45 Días por Año
#
# [79 rows x 16 columns]

# %%
max(tabulador["SUELDO BASE"])
# Out:
# '9,833.84'

# %%
tabulador.describe()
# Out:
#            NIVEL      ISSSTE
# count  79.000000   79.000000
# mean    8.670886  372.294304
# std     5.658489  257.337815
# min     1.000000   92.410000
# 25%     4.000000  136.930000
# 50%     8.000000  283.760000
# 75%    13.000000  680.420000
# max    22.000000  760.410000

# %%
import requests
import os

file = 'salarios_salarios_minimos.csv'
if not os.path.isfile(file):
  url = "https://idconline.mx/laboral/salarios-minimos/salarios-minimos-1986-2007"
  html = requests.get(url).content
  df_list = pd.read_html(html,header = 1)
  df=df_list[-1]
  df.to_csv('salarios_minimos.csv')
else:
  df = pd.read_csv(file)

df
# Out:
#    Fecha de publicación el DOF  Vigente a partir de:  ...       "B"       "C"
# 0      23 de diciembre de 2019        1o. enero 2020  ...       NaN       NaN
# 1      26 de diciembre de 2018        1o. enero 2019  ...       NaN       NaN
# 2      21 de diciembre de 2017        1o. enero 2018  ...       NaN       NaN
# 3      24 de noviembre de 2017    1o. diciembre 2017  ...       NaN       NaN
# 4      19 de diciembre de 2016        1o. enero 2017  ...       NaN       NaN
# 5      18 de diciembre de 2015        1o. enero 2016  ...       NaN       NaN
# 6     30 de septiembre de 2015   1o. octubre de 2015  ...       NaN       NaN
# 7          30 de marzo de 2015        1o. abril 2015  ...     68.28       NaN
# 8      29 de diciembre de 2014        1o. enero 2015  ...     66.45       NaN
# 9      26 de diciembre de 2013        1o. enero 2014  ...     63.77       NaN
# 10     21 de diciembre de 2012        1o. enero 2013  ...     61.38       NaN
# ...

# %%
df.describe()
# Out:
#        Fecha de publicación el DOF Vigente a partir de:  ...       "B"    "C"
# count                           45                   45  ...        38     34
# unique                          43                   45  ...        33     29
# top         2 de diciembre de 1996  4 de diciembre 1989  ...  11000.00  17.00
# freq                             2                    1  ...         2      2
#
# [4 rows x 7 columns]

# %%
#Tarea hacer graficos.
#percentiles cuartiles.
#Representacion de datos y analisis.
